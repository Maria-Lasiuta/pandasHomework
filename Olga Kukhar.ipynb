# %%
import pandas as pd

# %%
euro = pd.read_csv("Euro_2012_stats_TEAM.csv", index_col=0)
euro.head()
# Out:
#                 Goals  Shots on target  Shots off target Shooting Accuracy  \
# Team
# Croatia             4               13                12             51.9%
# Czech Republic      4               13                18             41.9%
# Denmark             4               10                10             50.0%
# England             5               11                18             50.0%
# France              3               22                24             37.9%
#
#                % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  \
# Team
# Croatia                   16.0%                          32             0
# Czech Republic            12.9%                          39             0
# Denmark                   20.0%                          27             1
# England                   17.2%                          40             0
# France                     6.5%                          65             1
#
# ...

# %%
pd.set_option('max_columns', None)
euro.head()
# Out:
#                 Goals  Shots on target  Shots off target Shooting Accuracy  \
# Team
# Croatia             4               13                12             51.9%
# Czech Republic      4               13                18             41.9%
# Denmark             4               10                10             50.0%
# England             5               11                18             50.0%
# France              3               22                24             37.9%
#
#                % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  \
# Team
# Croatia                   16.0%                          32             0
# Czech Republic            12.9%                          39             0
# Denmark                   20.0%                          27             1
# England                   17.2%                          40             0
# France                     6.5%                          65             1
#
# ...

# %% [markdown]
# *I have some problems with indexes, so decided to practice the easiest tasks*

# %% [markdown]
# **Select all columns except the last 15**

# %%
euro.iloc[:, :-15]
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %% [markdown]
# **How many interceptions Sweden made?**

# %%
euro.loc[['Sweden'], ['Interceptions']]
# Out:
#         Interceptions
# Team
# Sweden             45

# %% [markdown]
# **Select teams and amount of players (sorted)**

# %%
euro.iloc[:,-1].sort_values()
# Out:
# Team
# Denmark                15
# Netherlands            15
# Croatia                16
# England                16
# Portugal               16
# Russia                 16
# Germany                17
# Poland                 17
# Republic of Ireland    17
# Spain                  18
# Sweden                 18
# Ukraine                18
# Czech Republic         19
# France                 19
# Italy                  19
# Greece                 20
# Name: Players Used, dtype: int64

# %% [markdown]
# **Generate general information about column 'Passes'(amount of rows, mean value, min&max value...)**

# %%
euro.Passes.describe()
# Out:
# count      16.000000
# mean     1763.375000
# std       906.177898
# min       851.000000
# 25%      1190.750000
# 50%      1522.000000
# 75%      1934.750000
# max      4317.000000
# Name: Passes, dtype: float64

# %% [markdown]
# **Get a list of unique values(number of blocks) and how often they occur in the dataset**

# %%
euro.Blocks.value_counts()
# Out:
# 10    3
# 8     3
# 11    2
# 23    2
# 29    1
# 7     1
# 18    1
# 9     1
# 12    1
# 4     1
# Name: Blocks, dtype: int64

# %% [markdown]
# **What is the most frequent value of tackles?**

# %%
euro.groupby('Tackles').Tackles.count().idxmax()
# Out:
# 65

# %% [markdown]
# **Select countries that have at least 1 red card and more than 6 yellow cards**

# %%
euro[(euro['Red Cards'] != 0) & (euro['Yellow Cards'] > 6 )]
# Out:
#         Goals  Shots on target  Shots off target Shooting Accuracy  \
# Team
# Greece      5                8                18             30.7%
# Poland      2               15                23             39.4%
#
#        % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  \
# Team
# Greece            19.2%                          32             1
# Poland             5.2%                          48             0
#
#         Penalty goals  Penalties not scored  Headed goals  Passes  \
# Team
# Greece              1                     1             0    1187
# Poland              0                     0             1    1059
#
#         Passes completed Passing Accuracy  Touches  Crosses  Dribbles  \
# Team
# Greece               911            76.7%     2016       52        53
# Poland               852            80.4%     1724       55        39
#
#         Corners Taken  Tackles  Clearances  Interceptions  \
# Team
# ...
